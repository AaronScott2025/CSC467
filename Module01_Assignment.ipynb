# %%
# Part 1: Plot a Simple Quadratic Equation
import matplotlib.pyplot as plt
import numpy as np

# Generate x values
x = np.linspace(-10, 10, 100)

# Quadratic equation: y = x^2 - 4x + 5
y = x**2 - 4*x + 5

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = x^2 - 4x + 5', color='blue')
plt.title('Quadratic Equation Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %%
# Part 2: Plot an Image
import cv2
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
from skimage import io as io_url

# Load the image file (update the path to your image)
frame = io_url.imread('https://img.thedailybeast.com/image/upload/c_crop,d_placeholder_euli9k,h_1439,w_2560,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1492199514/articles/2014/05/10/remembering-weezer-s-the-blue-album-a-garage-rock-classic-on-its-20th-anniversary/140509-weezer-romano-tease_crohuc')
frame = np.float32(frame) / 255

plt.imshow(frame)
